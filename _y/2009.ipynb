# %% [markdown]
# ---
# permalink: "/y/2009"
# title: Lansări orbitale în 2009
# layout: default
# ---

# %%
# %store -r ylaunch
print(ylaunch[2009-1957])
# Out:
# În anul 2009 au avut loc un total de 78 tentative de lansări orbitale, din care 3 eșecuri.
# +----------------+-----------+---------+---------+
# | Țara           | Tentative | Reușite | Eșecuri |
# +----------------+-----------+---------+---------+
# | SUA            | 24        | 23      | 1       |
# | Rusia          | 33        | 33      | 0       |
# | China          | 6         | 6       | 0       |
# | Europa         | 7         | 7       | 0       |
# | Japonia        | 3         | 3       | 0       |
# | India          | 2         | 2       | 0       |
# | Iran           | 1         | 1       | 0       |
# | Coreea de Sud  | 1         | 0       | 1       |
# | Coreea de Nord | 2         | 0       | 2       |
# +----------------+-----------+---------+---------+
# +----------+------------------+---------------------+---------------------+-------------------------------------------+----+----------------+---+
# ...
